# %% [markdown]
# ### **Hypothesis Testing:**

# %% [markdown]
# #**Q1**.A F&B  manager wants to determine whether there is any significant difference in the diameter of cutlet between two units.A randomly selected sample of cutlets was collected from both units and measured? Analyze the data and draw inferences at 5% significance level.Please stat the assumptions and tests that you carried out to check validity of assumptions.

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # We will use **2 Tailed t-Test** to compare the mean of two indepedent samples.we will also check wether there is any significance difference between two sample or not.

# %% [markdown]
# # **Step-1**
#
# Make two hypothesis which contradicts to eachother.
#
#
#
# *   Null Hypothesis H0:µ1 =µ2
# *   Alternate Hypothesis H1:µ1 ≠µ2

# %% [markdown]
# # **Step-2**
#
#   Threshold value
#
# *   Significance 5%
# *   alpha =0.05
#
# Since we using 2 tailed t-Test so,
#  alpha = alpha/2
#
#
#  i.e,
#  alpha =0.025

# %% [markdown]
# # **Step-3**
# Import Files

# %%
from google.colab import files
uploded=files.upload()

# %%
cutlets=pd.read_csv("Cutlets.csv")

# %%
cutlets.head()

# %%
cutlets.shape

# %% [markdown]
# ## **Descriptive Statistics**

# %%
cutlets.describe()

# %% [markdown]
# # **Null  Values**

# %%
cutlets.isnull().sum()

# %% [markdown]
# # **Check Data Type**

# %%
cutlets.info()

# %% [markdown]
# # **Graphical representation**

# %%
plt.subplots(figsize = (10,8))
plt.subplot(121)
plt.boxplot(cutlets['Unit A'])
plt.title('Unit A')
plt.subplot(122)
plt.boxplot(cutlets['Unit B'])
plt.title('Unit B')
plt.show()

# %%
plt.subplots(figsize = (10,8))
plt.subplot(121)
plt.hist(cutlets['Unit A'], bins = 8)
plt.title('Unit A')
plt.subplot(122)
plt.hist(cutlets['Unit B'], bins = 8)
plt.title('Unit B')
plt.show()

# %% [markdown]
# #**Find P_value using Hypothesis t-statistics**

# %%
statistic , p_value = stats.ttest_ind(cutlets['Unit A'],cutlets['Unit B'], alternative = 'two-sided')
print('p_value=',p_value)

# %% [markdown]
# # **Compare p_value with**  **'α'(Significane Level)**
#
#
# If p_value is ≤' α ' we failed to reject Null Hypothesis because of lack of evidence
#
# If p_value is > 'α
#  ' we reject Null Hypothesis

# %%
alpha = 0.025
print('Significnace=%.3f, p=%.3f' % (alpha, p_value))
if p_value <= alpha:
    print('We reject Null Hypothesis there is a significance difference between two Units A and B')
else:
    print('We fail to reject Null hypothesis')

# %% [markdown]
# # **Therefore, we fail to reject null hypothesis this means there is no significant difference between given two samples.**

# %% [markdown]
# # **Q2**

# %% [markdown]
# ![Screenshot 2023-02-15 123404.png](data:image/png;base64,...)

# %% [markdown]
# # **Here, we will conduct ANOVA Test for 4 independent samples**
#
#
#
#
#
# # > **Step-1**
#
# ## **Create hypothesis:**
#
#
#  **Null Hypothesis**:µ1 =µ2=µ3 =µ4
#
#
#  **Alternate Hypothesis:**There is atleast one of them differs from the rest.
#
#
# # > **Step-2**
# ## **Threshold Value**
#
#
# *   Significance 5%
# *  alpha =0.05
#
#
# # >**Step-3**
# ## **Collect Data**

# %%
from google.colab import files
uploaded=files.upload()

# %%
labtat = pd.read_csv("LabTAT.csv")
labtat.head()

# %% [markdown]
# # **Descriptive Statistics**

# %%
labtat.describe()

# %% [markdown]
# # **Identify Null Values**

# %%
labtat.isnull().sum()

# %% [markdown]
# # **Check Data Type**

# %%
labtat.info()

# %% [markdown]
# #**Descriptive statistics**

# %%
labtat.describe()

# %% [markdown]
# # **Graphical Representation**

# %%
plt.subplots(figsize = (18,10))
plt.subplot(221)
plt.boxplot(labtat['Laboratory 1'])
plt.title('Laboratory 1')
plt.subplot(222)
plt.boxplot(labtat['Laboratory 2'])
plt.title('Laboratory 2')
plt.subplot(223)
plt.boxplot(labtat['Laboratory 3'])
plt.title('Laboratory 3')
plt.subplot(224)
plt.boxplot(labtat['Laboratory 4'])
plt.title('Laboratory 4')
plt.show()

# %%
plt.subplots(figsize = (10,8))
plt.subplot(221)
plt.hist(labtat['Laboratory 1'])
plt.title('Laboratory 1')
plt.subplot(222)
plt.hist(labtat['Laboratory 2'])
plt.title('Laboratory 2')
plt.subplot(223)
plt.hist(labtat['Laboratory 3'])
plt.title('Laboratory 3')
plt.subplot(224)
plt.hist(labtat['Laboratory 4'])
plt.title('Laboratory 4')
plt.show()

# %% [markdown]
# # >**Step-4**
# # **Conduct the one-way ANOVA Test**

# %%
test_statistic , p_value = stats.f_oneway(labtat.iloc[:,0],labtat.iloc[:,1],labtat.iloc[:,2],labtat.iloc[:,3])
print('p_value =',p_value)

# %% [markdown]
# **Here, we can observe , p_value is almost 0.**

# %% [markdown]
# # **Compare p_value with 'α'(Significane Level)**

# %% [markdown]
#  If p_value is ≤' α ' we failed to reject Null Hypothesis because of lack of evidence
#
# If p_value is > 'α
#  ' we reject Null Hypothesis

# %%
alpha = 0.05
print('Significnace=%.3f, p=%.3f' % (alpha, p_value))
if p_value <= alpha:
    print('We reject Null Hypothesis there is a significance difference between TAT of reports of the laboratories')
else:
    print('We fail to reject Null hypothesis')

# %% [markdown]
# # **Therefore, we fail to reject null hypothesis this means there is no significant difference between given two samples.**

# %% [markdown]
# # **Question-3**

# %% [markdown]
# ![Q3.png](data:image/png;base64,...)

# %% [markdown]
# # **Here, we will conduct The Chi squared χ² Test for 4 independent samples**
#
#
#
#
#
# # > **Step-1**
#
# ## **Create hypothesis:**
#
#
#  **Null Hypothesis**:There is no relationship between the gender based buyer rations across regions.
#
#
#  **Alternate Hypothesis:**There is significant relationship between the gender based buyer rations across regions.
#
#
# # > **Step-2**
# ## **Threshold Value**
#
#
# *  Significance 5%
# *  alpha =0.05
#
# Since it is one tailed test
# so, alpha = 0.05.
# # >**Step-3**
# ## **Import the Data**

# %%
from google.colab import files
uploaded=files.upload()

# %%
buyer = pd.read_csv("BuyerRatio.csv",index_col = 0)
buyer

# %% [markdown]
# # **Creating contingency Table**

# %%
table = [[50,142,131,70],
        [435,1523,1356,750]]

# %% [markdown]
# # Create Chi-Square contingency table

# %%
from scipy.stats import chi2_contingency

# %%
stat, p, dof, exp = chi2_contingency(buyer)

# %%
chi2_contingency(table)

# %%
observed = np.array([50, 142, 131, 70, 435, 1523, 1356, 750])
expected = np.array([42.76531299,  146.81287862,  131.11756787, 72.30424052, 442.23468701, 1518.18712138, 1355.88243213, 747.69575948])

# %% [markdown]
# # >**Step-5**
# ## **Interprete p_value**

# %%
alpha =0.05
print("statistics is "+str(stat),"\n""p_value is " + str(p))

# %% [markdown]
# # **Compare p_value with 'α'(Significane Level)**

# %% [markdown]
# If p_value is ≤' α ' we failed to reject Null Hypothesis because of lack of evidence
#
# If p_value is > 'α ' we reject Null Hypothesis

# %%
alpha = 0.05
print('Significnace=%.3f, p=%.3f' % (alpha, p_value))
if p_value <= alpha:
    print('We reject Null Hypothesis There is no relationship between the gender based buyer rations across regions.')
else:
    print('We fail to reject Null hypothesis')

# %% [markdown]
# # **We fail to reject Null Hypothesis that means there is no relationship between male-female buyers rations across regions. Hence, all the samples are Independent.**

# %% [markdown]
# # **Question-4**

# %% [markdown]
# ![Q4.png](data:image/png;base64,...)

# %% [markdown]
# # **Here, we are applying Test of independence using chi-square test**

# %% [markdown]
# # > **Step-1**
# # **Make Hypothesis:**
#
#
# ## 1.   **Null hypothesis**:% of defective in all countries are equal.
# ## 2.   **Alternate hypothesis**:% of defective are not equal in all countries .
#
#
#
# # > **Step-2**
#
# # **Decide Threshold value:**
#
# significance level = 5%.
# alpha = 0.05
#
#
#
#
# # > **Step-3**
# # **Collect all information regarding data:**

# %% [markdown]
# # **Import Files**

# %%
from google.colab import files
uploaded=files.upload()

# %%
centers=pd.read_csv("Costomer+OrderForm.csv")

# %%
centers

# %%
print(centers['Phillippines'].value_counts(),'\n',centers['Indonesia'].value_counts(),'\n',centers['Malta'].value_counts(),'\n',centers['India'].value_counts())

# %%
centers['Phillippines'].value_counts()

# %% [markdown]
# #**Create chi-square contegency table, appy chi-square test and interprete p_value**

# %%
#Create a contigency table
Tab_data=[[271,267,269,280],[29,33,31,20]]

# %%
Tab_data

# %%
stat, p, dof, exp = chi2_contingency(Tab_data)

# %%
chi2_contingency(Tab_data)

# %% [markdown]
# # **Observed values and Expected values**

# %%
observed = np.array([271, 267, 269, 280, 29, 33, 31, 20])
expected = np.array([271.75, 271.75, 271.75, 271.75, 28.25, 28.25, 28.25, 28.25])

# %% [markdown]
# # interprete p_value

# %%
alpha =0.05
print("statistics is "+str(stat),"\n""p_value is " + str(p))

# %% [markdown]
# # **Compare p_value with 'α'(Significane Level)**

# %% [markdown]
# If p_value is ≤' α ' we failed to reject Null Hypothesis
#
# If p_value is > 'α ' we reject Null Hypothesis

# %%
alpha = 0.05
print('Significnace=%.3f, p=%.3f' % (alpha, p_value))
if p_value <= alpha:
    print('We reject Null Hypothesis % of defective in all countries are equal. ')
else:
    print('We fail to reject Null hypothesis')

# %% [markdown]
# # **Thus,we fail to reject null hypothesis it means % of defective in all countries is equal.**
